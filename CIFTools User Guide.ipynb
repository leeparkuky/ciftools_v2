# %% [markdown]
# ## `acs_sdoh`

# %%
from CIFTools import acs_sdoh

# %% [markdown]
# Using `acs_sdoh`, you can not just download data for Cancer_InFocus but also for your own data project.
# Let's first take a look at how to download acs_sdoh data.
# `acs_sdoh` takes following arguments:
# * year: int
# * state_fips : str, int or list of str (2 digit state fips code)
# * query_level : str (possible values: 'state','county', 'tract','county subregion', 'block', 'zip'
# * key : census key
#
# You can sign up for the census key at : https://api.census.gov/data/key_signup.html
#
# In this tutorial, we will use the sample key that may already be expired by the time you read the tutorial

# %%
key = 'f1a4c4de1f35fe90fc1ceb60fd97b39c9a96e436' # provide the census api user key

# %%
sdoh = acs_sdoh(2019, ['21','22'], 'puma', key = key)

# %% [markdown]
# The function that you may call to scrap data for Cancer_InFocus is `cancer_infocus_download`.
# This function does not require any arguement

# %%
data_dictionary = sdoh.cancer_infocus_download()

# %%
data_dictionary['insurance']
# Out:
#    PUMA_ID                                          PUMA_NAME      State
# 0    00100            Purchase Area Development District PUMA   Kentucky  \
# 1    00200   Pennyrile Area Development District (North) PUMA   Kentucky
# 2    00300   Pennyrile Area Development District (South) PUMA   Kentucky
# 3    00400  Barren River Area Development District (Outer)...   Kentucky
# 4    00500  Barren River Area Development District (Centra...   Kentucky
# ..     ...                                                ...        ...
# 63   02302  Regional Planning Commission 5--Jefferson Pari...  Louisiana
# 64   02400  Regional Planning Commission 6--New Orleans Ci...  Louisiana
# 65   02401  Regional Planning Commission 7--New Orleans Ci...  Louisiana
# 66   02402  Regional Planning Commission 8--New Orleans Ci...  Louisiana
# 67   02500        Regional Planning Commission 9--St. Bernard  Louisiana
#
#     health_insurance_coverage_rate  medicaid
# 0                         0.943543  0.262831
# 1                         0.935507  0.252209
# 2                         0.907533  0.278923
# 3                         0.932068  0.305751
# 4                         0.945148  0.232757
# ..                             ...       ...
# 63                        0.884315  0.337925
# 64                        0.915558  0.335580
# 65                        0.883772  0.361050
# 66                        0.921396  0.214011
# 67                        0.904672  0.295947
#
# [68 rows x 5 columns]

# %% [markdown]
# `cancer_infocus_download()` returns a dictionary object with pandas dataframe as values as well as the corresponding dataset names as keys.

# %%
data_dictionary.keys()
# Out:
# dict_keys(['insurance', 'vacancy', 'poverty', 'transportation', 'employment', 'gini_index', 'rent_to_income', 'houses_before_1960', 'public_assistance', 'education', 'income', 'demographic_age', 'demographic_race'])

# %%
data_dictionary['demographic_age']
# Out:
#     FIPS                County                 State   Total  Under 18  \
# 0  11001  District of Columbia  District of Columbia  692683  0.178913
#
#    18 to 64   Over 64
# 0  0.700296  0.120791

# %%
data_dictionary['transportation'].head()
# Out:
#     FIPS             County      State  no_vehicle  two_or_more_vehicle  \
# 0  22001      Acadia Parish  Louisiana    0.012522             0.783917
# 1  22003       Allen Parish  Louisiana    0.010760             0.783041
# 2  22005   Ascension Parish  Louisiana    0.011004             0.837007
# 3  22007  Assumption Parish  Louisiana    0.024013             0.831469
# 4  22009   Avoyelles Parish  Louisiana    0.023306             0.752653
#
#    three_or_more_vehicle
# 0               0.345327
# 1               0.384327
# 2               0.364278
# 3               0.397807
# 4               0.318790

# %% [markdown]
# ### Query other dataset

# %% [markdown]
# To query other dataset, you may want to use `add_custom_table` function.
# The function requires the following three arguments:
# * group_id: acs group id (e.g. B01001)
#     - you can provide multiple group ids in a list (e.g. \["B01001", "C27007"\])
#     - However, all the acs groups must be in the same acs type
# * acs_type:
#     - '' : acs5
#     - 'profile' : acs5/profile
#     - 'subject' : acs5/subject
#     - for more information, please visit: https://api.census.gov/data.html
# * name: it will be a dictionary key for the dataset in the data_dictionary

# %% [markdown]
# Using the decorator of the `add_custom_table` you define how the dataframe to be organized since it is downloaded from the census.
# In the following example, the function does not change any from the raw data.

# %%
sdoh.clean_functions()

# %%
@sdoh.add_custom_table(["C27007", "B27001"], '', 'sample')
def download_custom_data(df):
    df = df.drop('B27001_001E', axis = 1)
    return df

# %%
data_dictionary = sdoh.download_all()

# %%
data_dictionary['sample'].head()
# Out:
#   PUMA_ID                                          PUMA_NAME     State
# 0   00100            Purchase Area Development District PUMA  Kentucky  \
# 1   00200   Pennyrile Area Development District (North) PUMA  Kentucky
# 2   00300   Pennyrile Area Development District (South) PUMA  Kentucky
# 3   00400  Barren River Area Development District (Outer)...  Kentucky
# 4   00500  Barren River Area Development District (Centra...  Kentucky
#
#   B27001_002E B27001_003E B27001_004E B27001_005E B27001_006E B27001_007E
# 0       93397        6903        6725         178       16009       15233  \
# 1       51371        3861        3710         151        9114        8597
# 2       45788        5549        5071         478        8901        8031
# 3       84472        7113        6462         651       15031       13956
# 4       62187        4760        4707          53       11248       11052
#
#   B27001_008E  ... C27007_012E C27007_013E C27007_014E C27007_015E
# 0         776  ...       99244       21908        9617       12291  \
# 1         517  ...       53772       11679        4807        6872
# 2         870  ...       49446       13660        5377        8283
# 3        1075  ...       87318       20653       10566       10087
# 4         196  ...       65156       16490        7028        9462
#
#   C27007_016E C27007_017E C27007_018E C27007_019E C27007_020E C27007_021E
# 0       56986       14467       42519       20350        2628       17722
# 1       31239        7741       23498       10854        1734        9120
# 2       27462        7831       19631        8324        1391        6933
# 3       50366       14442       35924       16299        2755       13544
# 4       40011        8583       31428        8655        1227        7428
#
# [5 rows x 80 columns]

# %%
sdoh.config.acs_group
# Out:
# ['C27007', 'B27001']

# %% [markdown]
# ### ACSConfig

# %% [markdown]
# When exploring an acs group, you may use `ACSConfig`.
# `ACSConfig` requires following arguements:
# * year : str or int
# * state_fips : a list of state fips or a single state fips as str
# * query_level: str
# * acs_group  : str or List[str]
# * acs_type   : str (optional)

# %%
from CIF_Config import ACSConfig
from pprint import pprint

# %%
cfg = ACSConfig(2020, 21, 'tract', ['B15003', 'B27001'], acs_type = '')

# %% [markdown]
# ACSConfig can provide both variables within the group and their labels.
# In addition, it also provides a table explaining details of each variable.

# %%
print(cfg.acs_group)
# Out:
# ['B15003', 'B27001']

# %%
print(cfg.variables)
# Out:
# ['B15003_001E', 'B15003_002E', 'B15003_003E', 'B15003_004E', 'B15003_005E', 'B15003_006E', 'B15003_007E', 'B15003_008E', 'B15003_009E', 'B15003_010E', 'B15003_011E', 'B15003_012E', 'B15003_013E', 'B15003_014E', 'B15003_015E', 'B15003_016E', 'B15003_017E', 'B15003_018E', 'B15003_019E', 'B15003_020E', 'B15003_021E', 'B15003_022E', 'B15003_023E', 'B15003_024E', 'B15003_025E', 'B27001_001E', 'B27001_002E', 'B27001_003E', 'B27001_004E', 'B27001_005E', 'B27001_006E', 'B27001_007E', 'B27001_008E', 'B27001_009E', 'B27001_010E', 'B27001_011E', 'B27001_012E', 'B27001_013E', 'B27001_014E', 'B27001_015E', 'B27001_016E', 'B27001_017E', 'B27001_018E', 'B27001_019E', 'B27001_020E', 'B27001_021E', 'B27001_022E', 'B27001_023E', 'B27001_024E', 'B27001_025E', 'B27001_026E', 'B27001_027E', 'B27001_028E', 'B27001_029E', 'B27001_030E', 'B27001_031E', 'B27001_032E', 'B27001_033E', 'B27001_034E', 'B27001_035E', 'B27001_036E', 'B27001_037E', 'B27001_038E', 'B27001_039E', 'B27001_040E', 'B27001_041E', 'B27001_042E', 'B27001_043E', 'B27001_044E', 'B27001_045E', 'B27001_046E', 'B27001_047E', 'B27001_048E', 'B27001_049E', 'B27001_050E', 'B27001_051E', 'B27001_052E', 'B27001_053E', 'B27001_054E', 'B27001_055E', 'B27001_056E', 'B27001_057E']

# %%
print(cfg.labels)
# Out:
# ['Total', 'No schooling completed', 'Nursery school', 'Kindergarten', '1st grade', '2nd grade', '3rd grade', '4th grade', '5th grade', '6th grade', '7th grade', '8th grade', '9th grade', '10th grade', '11th grade', '12th grade, no diploma', 'Regular high school diploma', 'GED or alternative credential', 'Some college, less than 1 year', 'Some college, 1 or more years, no degree', "Associate's degree", "Bachelor's degree", "Master's degree", 'Professional school degree', 'Doctorate degree', 'Total', 'Male', 'Total - Male - Under 6 years', 'Total - Male - Under 6 years - With health insurance coverage', 'Total - Male - Under 6 years - No health insurance coverage', 'Total - Male - 6 to 18 years', 'Total - Male - 6 to 18 years - With health insurance coverage', 'Total - Male - 6 to 18 years - No health insurance coverage', 'Total - Male - 19 to 25 years', 'Total - Male - 19 to 25 years - With health insurance coverage', 'Total - Male - 19 to 25 years - No health insurance coverage', 'Total - Male - 26 to 34 years', 'Total - Male - 26 to 34 years - With health insurance coverage', 'Total - Male - 26 to 34 years - No health insurance coverage', 'Total - Male - 35 to 44 years', 'Total - Male - 35 to 44 years - With health insurance coverage', 'Total - Male - 35 to 44 years - No health insurance coverage', 'Total - Male - 45 to 54 years', 'Total - Male - 45 to 54 years - With health insurance coverage', 'Total - Male - 45 to 54 years - No health insurance coverage', 'Total - Male - 55 to 64 years', 'Total - Male - 55 to 64 years - With health insurance coverage', 'Total - Male - 55 to 64 years - No health insurance coverage', 'Total - Male - 65 to 74 years', 'Total - Male - 65 to 74 years - With health insurance coverage', 'Total - Male - 65 to 74 years - No health insurance coverage', 'Total - Male - 75 years and over', 'Total - Male - 75 years and over - With health insurance coverage', 'Total - Male - 75 years and over - No health insurance coverage', 'Female', 'Total - Female - Under 6 years', 'Total - Female - Under 6 years - With health insurance coverage', 'Total - Female - Under 6 years - No health insurance coverage', 'Total - Female - 6 to 18 years', 'Total - Female - 6 to 18 years - With health insurance coverage', 'Total - Female - 6 to 18 years - No health insurance coverage', 'Total - Female - 19 to 25 years', 'Total - Female - 19 to 25 years - With health insurance coverage', 'Total - Female - 19 to 25 years - No health insurance coverage', 'Total - Female - 26 to 34 years', 'Total - Female - 26 to 34 years - With health insurance coverage', 'Total - Female - 26 to 34 years - No health insurance coverage', 'Total - Female - 35 to 44 years', 'Total - Female - 35 to 44 years - With health insurance coverage', 'Total - Female - 35 to 44 years - No health insurance coverage', 'Total - Female - 45 to 54 years', 'Total - Female - 45 to 54 years - With health insurance coverage', 'Total - Female - 45 to 54 years - No health insurance coverage', 'Total - Female - 55 to 64 years', 'Total - Female - 55 to 64 years - With health insurance coverage', 'Total - Female - 55 to 64 years - No health insurance coverage', 'Total - Female - 65 to 74 years', 'Total - Female - 65 to 74 years - With health insurance coverage', 'Total - Female - 65 to 74 years - No health insurance coverage', 'Total - Female - 75 years and over', 'Total - Female - 75 years and over - With health insurance coverage', 'Total - Female - 75 years and over - No health insurance coverage']

# %%
cfg.var_desc
# Out:
#            name                                              label
# 0   B27001_031E          Estimate!!Total:!!Female:!!Under 6 years:  \
# 1   B27001_032E  Estimate!!Total:!!Female:!!Under 6 years:!!Wit...
# 2   B27001_030E                          Estimate!!Total:!!Female:
# 3   B27001_023E  Estimate!!Total:!!Male:!!55 to 64 years:!!No h...
# 4   B27001_024E           Estimate!!Total:!!Male:!!65 to 74 years:
# ..          ...                                                ...
# 77  B15003_010E                        Estimate!!Total:!!6th grade
# 78  B15003_018E    Estimate!!Total:!!GED or alternative credential
# 79  B15003_019E   Estimate!!Total:!!Some college, less than 1 year
# 80  B15003_017E      Estimate!!Total:!!Regular high school diploma
# 81  B15003_016E           Estimate!!Total:!!12th grade, no diploma
#
#                                               concept
# 0      HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE
# 1      HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE
# 2      HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE
# 3      HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE
# 4      HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE
# ..                                                ...
# 77  EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 Y...
# 78  EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 Y...
# 79  EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 Y...
# 80  EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 Y...
# 81  EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 Y...
#
# [82 rows x 3 columns]

# %% [markdown]
# ## Downloading facility data

# %% [markdown]
# To download facility data, you simply need to use `gen_facility_data` function.
# The fuction requires only one arguement:
# * location : str or List\[str\] (abbreviation(s) of state name(s))

# %%
from CIFTools import gen_facility_data

# %%
facility_data = gen_facility_data(['KY','WV'])
# Out:
# Process is complete
# downloading fqhc data file: 100%|██████████| 12.4M/12.4M [00:00<00:00, 16.3MiB/s]
# downloading hpsa data file: 100%|██████████| 15.6M/15.6M [00:00<00:00, 17.7MiB/s]
# downloading lcs data file: 100%|██████████| 343k/343k [00:00<00:00, 431kiB/s]MiB/s]
# downloading toxRel data file: 100%|██████████| 73.0M/73.0M [00:02<00:00, 35.7MiB/s]

# %%
facility_data.keys()
# Out:
# dict_keys(['nppes', 'mammography', 'hpsa', 'fqhc', 'lung_cancer_screening', 'tri_facility', 'superfund_site'])

# %%
facility_data['hpsa']
# Out:
#                                                   Type  \
# 0                           HPSA Correctional Facility
# 1                             HPSA Rural Health Clinic
# 2                             HPSA Rural Health Clinic
# 3                             HPSA Rural Health Clinic
# 4                             HPSA Rural Health Clinic
# ..                                                 ...
# 101  HPSA Federally Qualified Health Center Look A ...
# 102                           HPSA Rural Health Clinic
# 103                           HPSA Rural Health Clinic
# 104                           HPSA Rural Health Clinic
# 105                           HPSA Rural Health Clinic
#
#                                               Name  \
# 0                                   FCC - Hazelton
# 1                     FAMILY HEALTHCARE ASSOCIATES
# 2    BOONE MEMORIAL HOSPITAL FAMILY MEDICAL CENTER
# 3                            ST MARYS EXPRESS CARE
# 4                     FAMILY HEALTHCARE ASSOCIATES
# ..                                             ...
# 101                          Faith Healthcare, Inc
# 102        PHYSICIAN SERVICES OF MEMORIAL HOSPITAL
# 103            FAMILY HEALTHCARE ASSOCIATES 7, LLC
# 104            FAMILY HEALTHCARE ASSOCIATES 8, LLC
# 105                 CUMBERLAND FAMILY CLINIC, PLLC
#
#                                              Address State Phone_number Notes  \
# 0          1640 Skyview Ln, Bruceton Mills, WV 26525    WV         None
# 1                         114 Main St, Man, WV 25635    WV         None
# 2                                                NaN    WV         None
# 3                  201 2nd St, Saint Marys, WV 26170    WV         None
# 4                  205 Howard Ave, Mullens, WV 25882    WV         None
# ..                                               ...   ...          ...   ...
# 101            126 Franklin Rd, Monticello, KY 42633    KY         None
# 102  94 Marie Langdon Dr STE 4, Manchester, KY 40962    KY         None
# 103         422 N Highway 27, Whitley City, KY 42653    KY         None
# 104             305 Danville Ave, Stanford, KY 40484    KY         None
# 105                 57 Hogue Rd, Pine Knot, KY 42635    KY         None
#
#       latitude  longitude
# 0    39.671864 -79.499303
# 1    37.743543 -81.874243
# 2    38.048889 -81.806171
# 3    39.389380 -81.207532
# 4    37.583248 -81.381166
# ..         ...        ...
# 101  36.866140 -84.827390
# 102  37.162858 -83.760707
# 103  36.817664 -84.486655
# 104  37.531983 -84.668236
# 105  36.665255 -84.441750
#
# [106 rows x 8 columns]

# %%
import pandas as pd
all_facility = pd.concat(facility_data.values(), axis = 0).reset_index(drop = True)

# %%
all_facility
# Out:
#                   Type                                   Name  \
# 0     Gastroenterology                          Marilyn Moaga
# 1     Gastroenterology                   Jeannine M Keeler RN
# 2     Gastroenterology              Samantha Bridges R.N. BSN
# 3     Gastroenterology                   Molly E Whitledge RN
# 4     Gastroenterology                Carole P Whitledge APRN
# ...                ...                                    ...
# 3819    Superfund Site        WEST VIRGINIA ORDNANCE (USARMY)
# 3820    Superfund Site  SHAFFER EQUIPMENT/ARBUCKLE CREEK AREA
# 3821    Superfund Site               VIENNA TETRACHLOROETHENE
# 3822    Superfund Site       NORTH 25TH STREET GLASS AND ZINC
# 3823    Superfund Site                         RAVENSWOOD PCE
#
#                                                 Address State  Phone_number  \
# 0               2513 Sun Seeker Ct, Lexington, KY 40503    KY  859-523-4442
# 1                  650 Joel Dr, Fort Campbell, KY 42223    KY  270-956-0297
# 2                  650 Joel Dr, Fort Campbell, KY 42223    KY  270-956-0489
# 3                  650 Joel Dr, Fort Campbell, KY 42223    KY  270-798-8422
# 4                    800 Zorn Ave, Louisville, KY 40206    KY  502-287-5894
# ...                                                 ...   ...           ...
# 3819          ROUTE 1 BOX 125, POINT PLEASANT, WV 25550    WV          None
# 3820  WV ROUTE 17 (A.K.A. MINDEN ROAD), MINDEN, WV 2...    WV          None
# 3821   30TH STREET, GRAND CENTRAL AVE, VIENNA, WV 26105    WV          None
# 3822               N. 25TH STREET, CLARKSBURG, WV 26301    WV          None
# 3823    212 WALNUT STREET APPROX., RAVENSWOOD, WV 26164    WV          None
#
#                            Notes   latitude  longitude   FIPS
# 0                                       NaN        NaN    NaN
# 1                                       NaN        NaN    NaN
# 2                                       NaN        NaN    NaN
# 3                                       NaN        NaN    NaN
# 4                                       NaN        NaN    NaN
# ...                          ...        ...        ...    ...
# 3819  Currently on the Final NPL  38.926389 -82.076389  54053
# 3820  Currently on the Final NPL   37.97651   -81.1265  54019
# 3821  Currently on the Final NPL  39.325167 -81.548778  54107
# 3822  Currently on the Final NPL  39.297053 -80.357433  54033
# 3823  Currently on the Final NPL  38.951667 -81.761667  54035
#
# [3824 rows x 9 columns]

# %% [markdown]
# ## Downloading Cancer Data

# %% [markdown]
# Cancer statistics are queries from https://www.statecancerprofiles.cancer.gov/
# To query cancer statistics, you first need to define `scp_cancer_data` with *state_fips* arguments.
# *state_fips* can be single state fips code in string format or a list of state fips code.

# %%
from CIFTools import scp_cancer_data
cancer = scp_cancer_data(['01','02'])

# %% [markdown]
# Then you can query data and retrieve it from `cancer_data` attribute, which is in a dictionary format with each value is a pandas DataFrame for incidence or mortality data.

# %%
cancer.cancer_data['incidence']
# Out:
#        FIPS          County    State       Type            Site    AAR  \
# 0     01000         Alabama  Alabama  Incidence        All Site  451.7
# 1     01000         Alabama  Alabama  Incidence         Bladder   17.7
# 2     01000         Alabama  Alabama  Incidence     Brain & ONS    6.4
# 3     01000         Alabama  Alabama  Incidence          Cervix    9.5
# 4     01000         Alabama  Alabama  Incidence  Colon & Rectum   42.4
# ...     ...             ...      ...        ...             ...    ...
# 1355  01133  Winston County  Alabama  Incidence           Ovary    NaN
# 1356  01133  Winston County  Alabama  Incidence        Pancreas   15.3
# 1357  01133  Winston County  Alabama  Incidence        Prostate  104.7
# 1358  01133  Winston County  Alabama  Incidence         Stomach    NaN
# 1359  01133  Winston County  Alabama  Incidence         Thyroid    NaN
#
#           AAC
# 0     27407.0
# 1      1092.0
# 2       360.0
# 3       241.0
# 4      2533.0
# ...       ...
# 1355      NaN
# 1356      6.0
# 1357     20.0
# 1358      NaN
# 1359      NaN
#
# [1360 rows x 7 columns]

# %% [markdown]
# ## Risk Behavior and Screening Data

# %% [markdown]
# CDC risk behavior and screening data is querried using Socrata API.
# You then need the followings:
# * domain : str =  "chronicdata.cdc.gov"
# * app_token : str = "nx4zQ2205wpLwaaaZeZp9zAOs"
# * user_name : str
# * password : str
#
# Then first define a SocrataConfig config object with the arguments above.
# It is okay to not have *user_name* and *password*, but it may cause a slow download of datasets

# %%
from CIF_Config import SocrataConfig

kwargs = {"domain": "chronicdata.cdc.gov",
      "app_token": "nx4zQ2205wpLwaaaZeZp9zAOs"}

cfg = SocrataConfig(**kwargs)

# %% [markdown]
# Then we provide the config object as well as state_fips (str or List\[str\]) to `places_data`

# %%
from CIFTools import places_data
cdc = places_data(['21','22'], cfg)

# %% [markdown]
# Then you can retrieve county-level and tract-level data from the `places_data` attribute

# %%
cdc.places_data
# Out:
# {'county':       FIPS         County      State Cancer_Prevalence Met_Cervical_Screen  \
#  0    21085        Grayson   Kentucky               7.5                78.3
#  1    21061       Edmonson   Kentucky               7.8                79.3
#  2    21223        Trimble   Kentucky               7.6                80.1
#  3    21075         Fulton   Kentucky               7.7                79.0
#  4    21179         Nelson   Kentucky               7.1                82.3
#  ..     ...            ...        ...               ...                 ...
#  179  22117     Washington  Louisiana               7.2                79.8
#  180  22103    St. Tammany  Louisiana               7.4                83.8
#  181  22031        De Soto  Louisiana               7.1                81.1
#  182  22077  Pointe Coupee  Louisiana               7.7                80.1
#  183  22013      Bienville  Louisiana               7.7                79.9
#
#      Met_Colon_Screen Currently_Smoke Met_Breast_Screen BMI_Obese
#  0               70.9            27.1              64.3      41.5
#  1               72.0            25.5              64.7      40.7
#  2               71.3            23.6              67.3      38.7
#  3               72.3            26.4              67.8      42.3
#  4               75.3            19.5              70.0      37.9
#  ..               ...             ...               ...       ...
#  179             69.7            24.3              73.6      43.8
#  180             75.7            16.7              78.9      31.3
#  181             71.1            22.6              74.9      42.6
#  182             70.5            21.5              73.1      40.6
#  183             68.6            24.6              75.1      43.9
#
#  [184 rows x 9 columns],
#  'tract':      State            County  FIPS5         FIPS Cancer_Prevalence  \
#  0       KY             Clark  21049  21049020500               7.3
#  1       KY         Henderson  21101  21101020500               6.7
#  2       KY        Montgomery  21173  21173920100               6.3
#  3       KY         Jefferson  21111  21111011106               6.3
#  4       KY            Warren  21227  21227011002               3.4
#  ...    ...               ...    ...          ...               ...
#  2225    LA        St. Landry  22097  22097960400               6.8
#  2226    LA         Jefferson  22051  22051020512               8.1
#  2227    LA           Orleans  22071  22071001701               7.4
#  2228    LA  West Baton Rouge  22121  22121020402               5.4
#  2229    LA            Iberia  22045  22045030100               6.2
#
#       Met_Colon_Screen Currently_Smoke Met_Breast_Screen BMI_Obese
#  0                76.1            18.1              76.2      33.3
#  1                70.5            24.2              73.2      42.1
#  2                72.8            22.3              72.5      37.5
#  3                74.1            19.6              75.4      35.7
#  4                67.8            24.0              76.1      38.8
#  ...               ...             ...               ...       ...
#  2225             64.0            29.6              75.0      35.3
#  2226             71.5            12.8              82.8      32.8
#  2227             72.1            17.7              84.7      36.6
#  2228             73.1            16.8              78.6      33.3
#  2229             69.9            23.2              80.2      38.5
#
#  [2230 rows x 9 columns]}

# %% [markdown]
# ## Downloading Food Desert Data

# %% [markdown]
# The food desert data is downloaded from the FDA: https://www.ers.usda.gov/data-products/food-access-research-atlas/download-the-data/
# Similar to `scp_cancer_data`, you first need to provide `food_desert` a state fips code or a list of state fips code if you have more than one state of interest.
# Another argument that `food_desert` requires is *var_name*. As default, the variable used in **Cancer InFocus** is **LILATracts_Vehicle** but if you have a different variable of your interest, you can provide the variable name. You can find variables from the link provided in the beginning.

# %%
from CIFTools import food_desert
fd = food_desert(['21','22'])

# %% [markdown]
# You can query and view the food desert data from the `food_desert_data` attribute.

# %%
fd.food_desert_data
# Out:
# downloading food desert data file: 100%|██| 81.8M/81.8M [00:02<00:00, 35.8MiB/s]
# {'Tract':               FIPS  LILATracts_Vehicle
#  0       1001020100                   0
#  1       1001020200                   0
#  2       1001020300                   0
#  3       1001020400                   0
#  4       1001020500                   0
#  ...            ...                 ...
#  62432  56043000200                   0
#  62433  56043000301                   0
#  62434  56043000302                   0
#  62435  56045951100                   0
#  62436  56045951300                   0
#
#  [62437 rows x 2 columns],
#  'County':        FIPS  LILATracts_Vehicle
#  0     10001            0.164720
#  1     10003            0.129582
#  2     10005            0.042145
#  3     10010            0.064586
#  4     10030            0.114731
#  ...     ...                 ...
#  3010  56037            0.137542
#  3011  56039            0.000000
#  3012  56041            0.343245
#  3013  56043            0.000000
#  3014  56045            0.000000
#
#  [3015 rows x 2 columns]}

# %% [markdown]
# ## Downloading Water Violation Data

# %% [markdown]
# `water_violation` class variable can provide you accumulate number of water violations in a given county between `start_year` and `end_year`. When `end_year` is **None**, which is a default value for the argument, it gives the total accumulate number of violations for the given county since the `start_year`. The default for `start_year` is 2016. If you want to retrieve information for a single year, make sure `start_year` == `end_year`.

# %%
from CIFTools import water_violation

wv = water_violation(['21','22'])

# %%
wv.water_violation_data
# Out:
#                              County      State  Counts
# 0                      Adair County   Kentucky     0.0
# 1                      Allen County   Kentucky     2.0
# 2                   Anderson County   Kentucky     2.0
# 3                    Ballard County   Kentucky     0.0
# 4                     Barren County   Kentucky     0.0
# ..                              ...        ...     ...
# 179           Webster Parish County  Louisiana    14.0
# 180  West Baton Rouge Parish County  Louisiana     0.0
# 181      West Carroll Parish County  Louisiana    11.0
# 182    West Feliciana Parish County  Louisiana     0.0
# 183              Winn Parish County  Louisiana    48.0
#
# [184 rows x 3 columns]

# %% [markdown]
# ## Downloading BLS Employment Data

# %% [markdown]
# While ACS5 provides 5 years estimates of unemployment rate, the BLS provides most recent county-wise unemployment numbers.
# `BLS` with a state_fips code(s) provides the data.

# %%
from CIFTools import BLS
bls = BLS(['21','22'])

# %%
bls.bls_data
# Out:
#       FIPS  Unemployment Rate  Period
# 0    21001                4.7  Nov-22
# 1    21003                3.7  Nov-22
# 2    21005                3.1  Nov-22
# 3    21007                4.4  Nov-22
# 4    21009                4.1  Nov-22
# ..     ...                ...     ...
# 179  22119                3.4  Nov-22
# 180  22121                2.6  Nov-22
# 181  22123                4.2  Nov-22
# 182  22125                2.0  Nov-22
# 183  22127                3.2  Nov-22
#
# [184 rows x 3 columns]
